-- %%
create table mytable_new
(
    col1 string,
    col2 int
)

-- %%
SELECT current_catalog()

-- %%
SELECT current_schema()

-- %%
DROP SCHEMA IF EXISTS pyspark_training CASCADE;

-- %%
CREATE SCHEMA pyspark_training;

-- %%
SELECT current_schema()

-- %%
USE SCHEMA pyspark_training;

-- %%
SELECT current_schema()

-- %%
create table mytable_new
(
    col1 string,
    col2 int
)

-- %%
CREATE VOLUME IF NOT EXISTS raw_data;

-- %% [markdown]
-- **Load data into volume for ingestion**

-- %% [markdown]
-- ![image_1782386830919.png](./image_1782386830919.png "image_1782386830919.png")

-- %% [markdown]
-- ![image_1782387046356.png](./image_1782387046356.png "image_1782387046356.png")

-- %% [markdown]
-- ![image_1782387097707.png](./image_1782387097707.png "image_1782387097707.png")

-- %% [markdown]
-- ![image_1782387126769.png](./image_1782387126769.png "image_1782387126769.png")
